# %%
import wandb
import pandas as pd
import os
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
artifact = wandb.use_artifact("sample.csv:latest")
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">driven-bird-7</strong> at: <a href='https://wandb.ai/kunal-chandmare/nyc_airbnb/runs/een68hep' target="_blank">https://wandb.ai/kunal-chandmare/nyc_airbnb/runs/een68hep</a><br> View project at: <a href='https://wandb.ai/kunal-chandmare/nyc_airbnb' target="_blank">https://wandb.ai/kunal-chandmare/nyc_airbnb</a><br>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260129_132252-een68hep\logs</code>
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>C:\Data\Repos\build-ml-pipeline-for-short-term-rental-prices\src\eda\wandb\run-20260129_140536-viy5xewk</code>
# Syncing run <strong><a href='https://wandb.ai/kunal-chandmare/nyc_airbnb/runs/viy5xewk' target="_blank">fiery-tree-8</a></strong> to <a href='https://wandb.ai/kunal-chandmare/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kunal-chandmare/nyc_airbnb' target="_blank">https://wandb.ai/kunal-chandmare/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/kunal-chandmare/nyc_airbnb/runs/viy5xewk' target="_blank">https://wandb.ai/kunal-chandmare/nyc_airbnb/runs/viy5xewk</a>

# %%
def safe_artifact_download_win(artifact):    
    artifact_dir = os.path.join(os.getcwd(), "my_safe_artifacts")
    print(f"Downloaded to: {artifact_dir}")
    artifact_folder = artifact.name.replace(":", "_")
    local_path = os.path.join(artifact_dir, artifact_folder)
    artifact_local_dir = artifact.download(root=local_path)
    return artifact_local_dir

# %%
artifact_dir = safe_artifact_download_win(artifact)
# Out:
# Downloaded to: C:\Data\Repos\build-ml-pipeline-for-short-term-rental-prices\src\eda\my_safe_artifacts
# wandb:   1 of 1 files downloaded.

# %%
csv_files = [f for f in os.listdir(artifact_dir) if f.lower().endswith('.csv')]
file_path = artifact_dir
if len(csv_files) == 1:
    file_path = os.path.join(artifact_dir, csv_files[0])
    df = pd.read_csv(file_path)
    print(f"Loaded: {csv_files[0]}  ({len(df)} rows)")    
else:
    print(f"Found {len(csv_files)} CSV files — expected exactly 1")
    if csv_files:
        print("Files:", csv_files)
    else:
        print("No CSV file found")
# Out:
# Loaded: sample1.csv  (20000 rows)

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8
